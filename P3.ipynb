# %%
#Q3

def nth_terms(a1,d,n):
 # a1 = first term of AP series
 #  d = commen difference
 # n = number to find value
 An = a1+(n-1)*d
 print(f" the value of {n}th terms is :",An)
     
# sum of nth terms 
def sum_of_nth_terms(a1,d,n):
 Sn = (n*(2*a1+(n-1)*d))//2
 print(f" the sum of up to {n}th terms is :",Sn)
